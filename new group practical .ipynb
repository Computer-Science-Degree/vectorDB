# %%
# !pip install chromadb sentence-transformers scikit-learn pandas numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 77.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 76.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 26.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.38.0
# ...

# %%
import chromadb

client = chromadb.Client()

print("ChromaDb version", chromadb.__version__)
print("Client created successfully")
# Out:
# ChromaDb version 1.5.9
# Client created successfully

# %% [markdown]
# Creating a collection \

# %%
collection = client.create_collection(name="my_first_collection")
print(f"Collection '{collection}' created successfully")
print(f"Number of items: {collection.count()}")
# Out:
# Collection 'Collection(name=my_first_collection)' created successfully
# Number of items: 0

# %% [markdown]
# # Insert Documents to collection \

# %%
# Insert some documents
collection.add(
    documents= [
        "Mchine learning helps the computer to learn from data",
        "Deep learning users neaurl networks with many layers ",
        "Pyhton is a popular programming language for data science",
        "The Effel tower is located in Paris, France",
        "Cats and dogs are common household pets"
    ],
    ids=["doc1", "doc2", "doc3", "doc4", "doc5"],
    metadatas=[
        {"category": "AI", "difficulty": "beginner"},
        {"category": "AI", "difficulty": "intermediate"},
        {"category": "programming", "difficulty": "beginner"},
        {"category": "geography", "difficulty": "beginner"},
        {"category": "animals", "difficulty": "beginner"},

    ]
)

print(f"Inserted documents. Collection now has {collection.count()} items.")
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:08<00:00, 9.26MiB/s]
# Inserted documents. Collection now has 5 items.

# %% [markdown]
# Query the collection
# \

# %%
# Query to find the 2 most similar documents to our question

results = collection.query(
    query_texts=["What is artifical intelligence "],
    n_results=2
)
print("\n----------query results ---------\n")
for i, (doc, distance, meta) in enumerate(zip(
    results["documents"][0],
    results["distances"][0],
    results["metadatas"][0])):

    print (f"\n Result  {i + 1}:")
    print(f"Document : {doc}")
    print(f"Distance: {distance:.4f} lower = more similar")
    print(f"Metadata: {meta}")
# Out:
# ----------query results ---------
#
#
#  Result  1:
# Document : Mchine learning helps the computer to learn from data
# Distance: 1.6130 lower = more similar
# Metadata: {'category': 'AI', 'difficulty': 'beginner'}
#
#  Result  2:
# Document : Pyhton is a popular programming language for data science
# Distance: 1.7898 lower = more similar
# Metadata: {'difficulty': 'beginner', 'category': 'programming'}
